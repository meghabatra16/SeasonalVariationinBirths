# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
birth = pd.read_csv("/Users/meghabatra/Downloads/BirthMonthsData.csv")
birth
# Out:
#                  Country or Area  Year   Area      Month  \
# 0                  Åland Islands  2019  Total      Total
# 1                  Åland Islands  2019  Total    January
# 2                  Åland Islands  2019  Total   February
# 3                  Åland Islands  2019  Total      March
# 4                  Åland Islands  2019  Total      April
# ...                          ...   ...    ...        ...
# 53404  Wallis and Futuna Islands  1973  Total     August
# 53405  Wallis and Futuna Islands  1973  Total  September
# 53406  Wallis and Futuna Islands  1973  Total    October
# 53407  Wallis and Futuna Islands  1973  Total   November
# 53408  Wallis and Futuna Islands  1973  Total   December
#
#                                 Record Type             Reliability  \
# 0      Data tabulated by year of occurrence  Final figure, complete
# 1      Data tabulated by year of occurrence  Final figure, complete
# 2      Data tabulated by year of occurrence  Final figure, complete
# ...

# %%
birth["Country or Area"].unique()
# Out:
# array(['Åland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Bermuda',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Cabo Verde', 'Canada', 'Cayman Islands', 'Chile',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'Cook Islands',
#        'Costa Rica', 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        'Denmark', 'Egypt', 'El Salvador', 'Estonia',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Guiana', 'French Polynesia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guyana', 'Hungary',
# ...

# %%
birth.shape
# Out:
# (53409, 7)

# %%
birth.Number_of_Births.describe()
# Out:
# count    5.340900e+04
# mean     3.889705e+04
# std      1.768072e+05
# min      0.000000e+00
# 25%      4.970000e+02
# 50%      5.244000e+03
# 75%      2.092300e+04
# max      4.265555e+06
# Name: Number_of_Births, dtype: float64

# %%
birth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53409 entries, 0 to 53408
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country or Area   53409 non-null  object
#  1   Year              53409 non-null  int64
#  2   Area              53409 non-null  object
#  3   Month             53409 non-null  object
#  4   Record Type       53409 non-null  object
#  5   Reliability       53409 non-null  object
#  6   Number_of_Births  53409 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ MB

# %%
birth.columns
# Out:
# Index(['Country or Area', 'Year', 'Area', 'Month', 'Record Type',
#        'Reliability', 'Number_of_Births'],
#       dtype='object')

# %%
birth.isnull().sum()
# Out:
# Country or Area     0
# Year                0
# Area                0
# Month               0
# Record Type         0
# Reliability         0
# Number_of_Births    0
# dtype: int64

# %%
y = birth.groupby("Year")
y

# %%
b1 = y["Number_of_Births"].sum().reset_index()
b1
# Out:
#     Year  Number_of_Births
# 0   1967      7.142780e+05
# 1   1968      7.076360e+05
# 2   1969      1.059058e+07
# 3   1970      1.488850e+07
# 4   1971      1.800115e+07
# 5   1972      1.987243e+07
# 6   1973      2.941405e+07
# 7   1974      3.364105e+07
# 8   1975      3.153059e+07
# 9   1976      2.975218e+07
# 10  1977      2.633506e+07
# 11  1978      4.062025e+07
# 12  1979      4.164991e+07
# 13  1980      3.566287e+07
# 14  1981      3.596452e+07
# 15  1982      3.494210e+07
# 16  1983      3.332421e+07
# 17  1984      3.898922e+07
# 18  1985      4.223600e+07
# 19  1986      3.924764e+07
# 20  1987      3.928296e+07
# 21  1988      4.021602e+07
# 22  1989      3.933610e+07
# 23  1990      4.152616e+07
# 24  1991      4.464485e+07
# 25  1992      4.802412e+07
# 26  1993      4.584578e+07
# 27  1994      4.755536e+07
# 28  1995      4.019217e+07
# 29  1996      3.651954e+07
# 30  1997      3.906142e+07
# 31  1998      3.616679e+07
# 32  1999      4.520822e+07
# ...

# %%
b1.columns = ["Year", "TotalBirths"]
b1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a2d81d17985> in <module>
# ----> 1 b1.columns = ["Year", "TotalBirths"]
#       2 b1
#
# NameError: name 'b1' is not defined

# %%
ax = sns.catplot(x="Year",
                y="TotalBirths",
                kind="bar", 
                data=b1, height = 8,aspect = 3, legend = True).set(title='Number of births each year')

# %%
birth["Month"].value_counts()
# Out:
# Total                 4072
# January               4072
# April                 4068
# March                 4062
# May                   4056
# February              4054
# July                  4051
# June                  4047
# October               4041
# September             4038
# August                4037
# November              4031
# December              4024
# Unknown                491
# January - March         72
# April - June            65
# October - December      64
# July - September        64
# Name: Month, dtype: int64

# %%
update_birth = birth
update_birth = update_birth.drop(birth[birth["Month"] == "Total"].index)
update_birth = update_birth.drop(birth[birth["Month"] == "January - March"].index)
update_birth = update_birth.drop(birth[birth["Month"] == "April - June"].index)
update_birth = update_birth.drop(birth[birth["Month"] == "October - December"].index) 
update_birth = update_birth.drop(birth[birth["Month"] == "July - September"].index)
update_birth = update_birth.drop(birth[birth["Month"] == "Unknown"].index)
update_birth["Month"].value_counts()
# Out:
# January      4072
# April        4068
# March        4062
# May          4056
# February     4054
# July         4051
# June         4047
# October      4041
# September    4038
# August       4037
# November     4031
# December     4024
# Name: Month, dtype: int64

# %%
a =update_birth.groupby("Country or Area")
a
b = a["Number_of_Births"].sum().reset_index()
b
sort1= b.sort_values(by = 'Number_of_Births', ascending = False)
sort1
top_ =sort1.head(10)
top_
# Out:
#               Country or Area  Number_of_Births
# 147  United States of America       180090670.0
# 38                      Egypt        89740084.0
# 67                      Japan        63472859.0
# 100                  Pakistan        62310871.0
# 104               Philippines        44060963.0
# 113        Russian Federation        36172366.0
# 45                     France        33959084.0
# 109         Republic of Korea        32560989.0
# 65                      Italy        28638779.0
# 130                     Spain        22935002.0

# %%
ax = sns.catplot(x="Country or Area",
                y="Number_of_Births",
                kind="bar", 
                data=top_, height = 8,aspect = 3, legend = True).set(title='Top 10 Countries by Maximum Births')

# %%
update_birth["Record Type"]
# Out:
# 1        Data tabulated by year of occurrence
# 2        Data tabulated by year of occurrence
# 3        Data tabulated by year of occurrence
# 4        Data tabulated by year of occurrence
# 5        Data tabulated by year of occurrence
#                          ...
# 53404    Data tabulated by year of occurrence
# 53405    Data tabulated by year of occurrence
# 53406    Data tabulated by year of occurrence
# 53407    Data tabulated by year of occurrence
# 53408    Data tabulated by year of occurrence
# Name: Record Type, Length: 48581, dtype: object

# %%
Records = update_birth["Record Type"].value_counts().reset_index()
Records
# Out:
#                                     index  Record Type
# 0    Data tabulated by year of occurrence        42018
# 1  Data tabulated by year of registration         6551
# 2            Vital statistics from census           12

# %%
plot = Records.plot.pie(y='Record Type', figsize=(5, 5))

# %%
Reliability_record = update_birth["Reliability"].value_counts().reset_index()
Reliability_record
# Out:
#                     index  Reliability
# 0  Final figure, complete        46276
# 1      Provisional figure         1801
# 2          Other estimate          504

# %%
sns.barplot(x= "Index", y = "Reliability", Reliability_record)
# Out:
#   File "<ipython-input-368-84b2ef9675a3>", line 1
#     sns.barplot(x= "Index", y = "Reliability", Reliability_record)
#                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
Births = update_birth.groupby("Month")["Number_of_Births"].sum().reset_index()
sort= Births.sort_values(by = 'Month', ascending = False)
sort
sort.columns = ["Months", "Number_of_Births_each_month"]

# %%
ax = sns.catplot(x="Months",
                y="Number_of_Births_each_month",
                kind="bar", 
                data=sort, height = 8,aspect = 4, legend = True).set(title='Births each month')

# %%
birth.head()
# Out:
#   Country or Area  Year   Area     Month  \
# 0   Åland Islands  2019  Total     Total
# 1   Åland Islands  2019  Total   January
# 2   Åland Islands  2019  Total  February
# 3   Åland Islands  2019  Total     March
# 4   Åland Islands  2019  Total     April
#
#                             Record Type             Reliability  \
# 0  Data tabulated by year of occurrence  Final figure, complete
# 1  Data tabulated by year of occurrence  Final figure, complete
# 2  Data tabulated by year of occurrence  Final figure, complete
# 3  Data tabulated by year of occurrence  Final figure, complete
# 4  Data tabulated by year of occurrence  Final figure, complete
#
#    Number_of_Births
# 0             267.0
# 1              28.0
# 2              24.0
# 3              26.0
# 4              16.0

# %%
birth['Month'] = birth['Month'].replace(['January - March','April - June',"October - December","July - September"],['Spring','Summer','Winter','Fall/Autumn'])

# %%
birth
# Out:
#                  Country or Area  Year   Area      Month  \
# 0                  Åland Islands  2019  Total      Total
# 1                  Åland Islands  2019  Total    January
# 2                  Åland Islands  2019  Total   February
# 3                  Åland Islands  2019  Total      March
# 4                  Åland Islands  2019  Total      April
# ...                          ...   ...    ...        ...
# 53404  Wallis and Futuna Islands  1973  Total     August
# 53405  Wallis and Futuna Islands  1973  Total  September
# 53406  Wallis and Futuna Islands  1973  Total    October
# 53407  Wallis and Futuna Islands  1973  Total   November
# 53408  Wallis and Futuna Islands  1973  Total   December
#
#                                 Record Type             Reliability  \
# 0      Data tabulated by year of occurrence  Final figure, complete
# 1      Data tabulated by year of occurrence  Final figure, complete
# 2      Data tabulated by year of occurrence  Final figure, complete
# ...

# %%
birth["Month"].value_counts()
# Out:
# Total          4072
# January        4072
# April          4068
# March          4062
# May            4056
# February       4054
# July           4051
# June           4047
# October        4041
# September      4038
# August         4037
# November       4031
# December       4024
# Unknown         491
# Spring           72
# Summer           65
# Fall/Autumn      64
# Winter           64
# Name: Month, dtype: int64

# %%
birth_update = birth.copy()

# %%
birth_update = birth_update.drop(birth[birth["Month"] == "Total"].index)
birth_update = birth_update.drop(birth[birth["Month"] == "Unknown"].index)

# %%
birth_update["Month"].value_counts()
# Out:
# January        4072
# April          4068
# March          4062
# May            4056
# February       4054
# July           4051
# June           4047
# October        4041
# September      4038
# August         4037
# November       4031
# December       4024
# Spring           72
# Summer           65
# Fall/Autumn      64
# Winter           64
# Name: Month, dtype: int64

# %%
birth_update
# Out:
#                  Country or Area  Year   Area      Month  \
# 1                  Åland Islands  2019  Total    January
# 2                  Åland Islands  2019  Total   February
# 3                  Åland Islands  2019  Total      March
# 4                  Åland Islands  2019  Total      April
# 5                  Åland Islands  2019  Total        May
# ...                          ...   ...    ...        ...
# 53404  Wallis and Futuna Islands  1973  Total     August
# 53405  Wallis and Futuna Islands  1973  Total  September
# 53406  Wallis and Futuna Islands  1973  Total    October
# 53407  Wallis and Futuna Islands  1973  Total   November
# 53408  Wallis and Futuna Islands  1973  Total   December
#
#                                 Record Type             Reliability  \
# 1      Data tabulated by year of occurrence  Final figure, complete
# 2      Data tabulated by year of occurrence  Final figure, complete
# 3      Data tabulated by year of occurrence  Final figure, complete
# ...

# %%
Month_wise = birth_update.groupby('Month')["Number_of_Births"].sum().reset_index()
Month_wise
sort= Month_wise.sort_values(by = 'Number_of_Births', ascending = False)
sort
# Out:
#           Month  Number_of_Births
# 12    September      9.102049e+07
# 5       January      9.074046e+07
# 1        August      9.066047e+07
# 6          July      8.995628e+07
# 11      October      8.938985e+07
# 8         March      8.614845e+07
# 9           May      8.542745e+07
# 2      December      8.459278e+07
# 7          June      8.456673e+07
# 10     November      8.442779e+07
# 0         April      8.275809e+07
# 4      February      8.053375e+07
# 13       Spring      1.406257e+06
# 14       Summer      1.366205e+06
# 3   Fall/Autumn      1.232431e+06
# 15       Winter      1.165227e+06

# %%
sort.columns = ["Month","Number_of_Births_each_month"]

# %%
ax = sns.catplot(x="Month",
                y="Number_of_Births_each_month",
                kind="bar", 
                data=sort, height = 8,aspect = 4, legend = True).set(title='Births each month')

# %%
Dict = dict({"January" :1, 'February' :2 ,'March':3, "April":4,"May":5, "June":6, "July":7,"August":8,"September":9,"October":10,"November":11,"December":12})
update_birth["Month_no"] = update_birth.Month.map(Dict)

# %%
update_birth
# Out:
#                  Country or Area  Year   Area      Month  \
# 1                  Åland Islands  2019  Total    January
# 2                  Åland Islands  2019  Total   February
# 3                  Åland Islands  2019  Total      March
# 4                  Åland Islands  2019  Total      April
# 5                  Åland Islands  2019  Total        May
# ...                          ...   ...    ...        ...
# 53404  Wallis and Futuna Islands  1973  Total     August
# 53405  Wallis and Futuna Islands  1973  Total  September
# 53406  Wallis and Futuna Islands  1973  Total    October
# 53407  Wallis and Futuna Islands  1973  Total   November
# 53408  Wallis and Futuna Islands  1973  Total   December
#
#                                 Record Type             Reliability  \
# 1      Data tabulated by year of occurrence  Final figure, complete
# 2      Data tabulated by year of occurrence  Final figure, complete
# 3      Data tabulated by year of occurrence  Final figure, complete
# ...
